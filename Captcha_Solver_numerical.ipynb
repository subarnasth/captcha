# %% [markdown]
# <a href="https://colab.research.google.com/github/subarnasth/captcha/blob/master/Captcha_Solver_numerical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install captcha 
# %pip install opencv-python
# !apt update && apt install -y libsm6 libxext6
# !pip install opencv-python-headless
# !pip install opencv-contrib-python-headless
# %pip install keras


import argparse
import json
import string
import os
import shutil
import uuid
from captcha.image import ImageCaptcha

import itertools

import os
import cv2
import numpy as np
from random import random, randint, choices

import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
import matplotlib.pyplot as plt
# Out:
# Collecting captcha
#   Downloading https://files.pythonhosted.org/packages/90/fe/d4ddf1e6576073b5eaea76e9b2afa022c626212a30c871968480be3ccb7b/captcha-0.3-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 2.7MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from captcha) (7.0.0)
# Installing collected packages: captcha
# Successfully installed captcha-0.3
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.5)
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [95.7 kB]
# Get:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [892 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,067 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [109 kB]
# Get:18 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [47.5 kB]
# Get:19 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,421 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,864 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,362 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [125 kB]
# Get:24 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [900 kB]
# Fetched 8,220 kB in 3s (2,401 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 72 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.2-1).
# libxext6 is already the newest version (2:1.3.3-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 72 not upgraded.
# Collecting opencv-python-headless
#   Downloading https://files.pythonhosted.org/packages/b6/2a/496e06fd289c01dc21b11970be1261c87ce1cc22d5340c14b516160822a7/opencv_python_headless-4.4.0.42-cp36-cp36m-manylinux2014_x86_64.whl (36.6MB)
#      |████████████████████████████████| 36.6MB 83kB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python-headless) (1.18.5)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.4.0.42
# Collecting opencv-contrib-python-headless
#   Downloading https://files.pythonhosted.org/packages/6e/a7/42a670058696ffe88f6408e1fc8b6424053ad56246e599aa1f31f01f62b1/opencv_contrib_python_headless-4.4.0.42-cp36-cp36m-manylinux2014_x86_64.whl (42.8MB)
#      |████████████████████████████████| 42.8MB 72kB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from opencv-contrib-python-headless) (1.18.5)
# Installing collected packages: opencv-contrib-python-headless
# Successfully installed opencv-contrib-python-headless-4.4.0.42
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras) (1.15.0)

# %%
def _gen_captcha(img_dir, num_of_letters, num_of_repetition, width, height):
    if os.path.exists(img_dir):
        shutil.rmtree(img_dir)
    if not os.path.exists(img_dir):
        os.makedirs(img_dir)

    image = ImageCaptcha(width=width, height=height)

    for counter in range(num_of_repetition):
        print('generating %d/%d' % (counter + 1, num_of_repetition))
        for i in itertools.permutations([str(c) for c in range(10)], num_of_letters):
            captcha = ''.join(i)
            fn = os.path.join(img_dir, '%s_%s.png' % (captcha, uuid.uuid4()))
            image.write(captcha, fn)


def gen_dataset(path, num_of_repetition, num_of_letters, width, height):
    _gen_captcha(os.path.join(path, 'data'), num_of_letters, num_of_repetition, width, height)
    print('Finished Data Generation')

# %%
BATCH_SIZE = 128
NUM_OF_LETTERS = 5
EPOCHS = 50
IMG_ROW, IMG_COLS = 50, 135


# Non-configs
PATH = os.getcwd()
DATA_PATH = os.path.join(PATH, 'train')

# %%
def load_data(path, test_split=0.1):
    print ('loading dataset...')
    y_train = []
    y_test = []
    x_train = []
    x_test = []

    # r=root, d=directories, f = files
    counter = 0
    for r, d, f in os.walk(path):
        for fl in f:
            if '.png' in fl:
                flr = fl.split('_')[0]
                counter += 1
                label = np.zeros((NUM_OF_LETTERS, 10))
                for i in range(NUM_OF_LETTERS):
                    label[i, int(flr[i])] = 1

                img = cv2.imread(os.path.join(r, fl))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img = cv2.resize(img, (int(135/2), int(50/2)), interpolation=cv2.INTER_AREA)
                img = np.reshape(img, (img.shape[0], img.shape[1], 1))

                if random() < test_split:
                    y_test.append(label)
                    x_test.append(img)
                else:
                    y_train.append(label)
                    x_train.append(img)

    print('dataset size:', counter, '(train=%d, test=%d)' % (len(y_train), len(y_test)))
    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

# %%
if not os.path.exists(DATA_PATH):
    print('Generating Dataset')
    gen_dataset(DATA_PATH, 8 , NUM_OF_LETTERS, IMG_COLS, IMG_ROW)
# Out:
# Generating Dataset
# generating 1/8
# generating 2/8
# generating 3/8
# generating 4/8
# generating 5/8
# generating 6/8
# generating 7/8
# generating 8/8
# Finished Data Generation

# %%
x_train, y_train, x_test, y_test = load_data(DATA_PATH)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# Out:
# loading dataset...
# dataset size: 241920 (train=217814, test=24106)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (217814, 25, 67, 1)
# (217814, 5, 10)
# (24106, 25, 67, 1)
# (24106, 5, 10)

# %%
s_train = []
s_test = []
for i in range(NUM_OF_LETTERS):
    s_train.append(y_train[:, i, :])
    s_test.append(y_test[:, i, :])

# %%
save_dir = os.path.join(PATH, 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# %%
input_layer = Input((25, 67, 1))
x = Conv2D(filters=32, kernel_size=(5, 5), padding='same', activation='relu')(input_layer)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=48, kernel_size=(5, 5), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Dropout(0.3)(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)

out = [Dense(10, name='digit%d' % i, activation='softmax')(x) for i in range(NUM_OF_LETTERS)]
model = Model(inputs=input_layer, outputs=out)

# %%
# Uncomment these if you want to load and continue an already trained network

# model_path = os.path.join(save_dir, model_name)
# model = keras.models.load_model(model_path)

# %%
# initiate Adam optimizer

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])


model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 25, 67, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 25, 67, 32)   832         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 33, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 12, 33, 48)   38448       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 6, 16, 48)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 6, 16, 64)    76864       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 3, 8, 64)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 3, 8, 64)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1536)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      flatten[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# digit0 (Dense)                  (None, 10)           5130        dropout_1[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 10)           5130        dropout_1[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 10)           5130        dropout_1[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 10)           5130        dropout_1[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 10)           5130        dropout_1[0][0]
# ==================================================================================================
# Total params: 928,738
# Trainable params: 928,738
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist_train_loss_digit = {i:[] for i in range(5)}
hist_test_loss_digit = {i:[] for i in range(5)}

hist_train_acc_digit = {i:[] for i in range(5)}
hist_test_acc_digit = {i:[] for i in range(5)}

hist_train_loss = []
hist_test_loss = []

hist_train_acc = []
hist_test_acc = []

# %%
digit_acc = [[] for _ in range(NUM_OF_LETTERS)]
val_digit_acc = [[] for _ in range(NUM_OF_LETTERS)]
loss = []
val_loss = []

# %%
history = model.fit(x_train, s_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=(x_test, s_test)
                   )
# Out:
# Epoch 1/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0991 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.0988 - digit4_accuracy: 0.0995 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.0979
# Epoch 2/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0999 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.0992 - digit4_accuracy: 0.0997 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.1027 - val_digit2_accuracy: 0.0982 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0979
# Epoch 3/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0991 - digit1_accuracy: 0.1003 - digit2_accuracy: 0.0981 - digit3_accuracy: 0.1007 - digit4_accuracy: 0.0989 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.0987
# Epoch 4/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0992 - digit1_accuracy: 0.0998 - digit2_accuracy: 0.1007 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.1000 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.0993 - val_digit3_accuracy: 0.1030 - val_digit4_accuracy: 0.1026
# Epoch 5/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0990 - digit1_accuracy: 0.0993 - digit2_accuracy: 0.0999 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.0998 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1009 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0987
# Epoch 6/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1004 - digit1_accuracy: 0.0989 - digit2_accuracy: 0.0986 - digit3_accuracy: 0.0992 - digit4_accuracy: 0.0992 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1011 - val_digit1_accuracy: 0.0995 - val_digit2_accuracy: 0.0979 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.1014
# Epoch 7/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0988 - digit1_accuracy: 0.1002 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.1002 - digit4_accuracy: 0.0984 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.1009 - val_digit4_accuracy: 0.1004
# Epoch 8/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0988 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.0989 - digit4_accuracy: 0.0996 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.1004
# Epoch 9/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.0991 - digit2_accuracy: 0.0993 - digit3_accuracy: 0.0993 - digit4_accuracy: 0.0996 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.1001 - val_digit2_accuracy: 0.0979 - val_digit3_accuracy: 0.0978 - val_digit4_accuracy: 0.0987
# Epoch 10/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0989 - digit1_accuracy: 0.0992 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.0996 - digit4_accuracy: 0.1001 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.0978 - val_digit4_accuracy: 0.1004
# Epoch 11/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.0996 - digit2_accuracy: 0.0996 - digit3_accuracy: 0.0988 - digit4_accuracy: 0.0991 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1018 - val_digit1_accuracy: 0.1029 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.1007
# Epoch 12/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1000 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0995 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.0995 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0979
# Epoch 13/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1000 - digit1_accuracy: 0.0986 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.1006 - digit4_accuracy: 0.0998 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.0982 - val_digit3_accuracy: 0.0978 - val_digit4_accuracy: 0.1026
# Epoch 14/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1002 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.1001 - digit4_accuracy: 0.1007 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.1001 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.0987
# Epoch 15/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0993 - digit1_accuracy: 0.1000 - digit2_accuracy: 0.1001 - digit3_accuracy: 0.0997 - digit4_accuracy: 0.0989 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0995 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.0979
# Epoch 16/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0998 - digit1_accuracy: 0.1001 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.0996 - digit4_accuracy: 0.0993 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.0986 - val_digit4_accuracy: 0.1007
# Epoch 17/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0993 - digit1_accuracy: 0.0989 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.1006 - digit4_accuracy: 0.1002 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0979
# Epoch 18/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0995 - digit1_accuracy: 0.0991 - digit2_accuracy: 0.0996 - digit3_accuracy: 0.0983 - digit4_accuracy: 0.0992 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.0982 - val_digit3_accuracy: 0.0978 - val_digit4_accuracy: 0.0987
# Epoch 19/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1002 - digit1_accuracy: 0.1004 - digit2_accuracy: 0.0994 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.0993 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1011 - val_digit1_accuracy: 0.0995 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0986 - val_digit4_accuracy: 0.0987
# Epoch 20/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0989 - digit1_accuracy: 0.0992 - digit2_accuracy: 0.0994 - digit3_accuracy: 0.0989 - digit4_accuracy: 0.1000 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1011 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.1020 - val_digit4_accuracy: 0.0975
# Epoch 21/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1002 - digit1_accuracy: 0.0987 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.0989 - digit4_accuracy: 0.0993 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1018 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.0979 - val_digit3_accuracy: 0.1044 - val_digit4_accuracy: 0.0987
# Epoch 22/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0999 - digit1_accuracy: 0.0979 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.0999 - digit4_accuracy: 0.0998 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1018 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.0979 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.0979
# Epoch 23/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0993 - digit1_accuracy: 0.0995 - digit2_accuracy: 0.0980 - digit3_accuracy: 0.0997 - digit4_accuracy: 0.1001 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.0990 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.1004
# Epoch 24/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0992 - digit1_accuracy: 0.0988 - digit2_accuracy: 0.0996 - digit3_accuracy: 0.0992 - digit4_accuracy: 0.0997 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0994 - val_digit1_accuracy: 0.1006 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.1009 - val_digit4_accuracy: 0.0987
# Epoch 25/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0995 - digit1_accuracy: 0.1002 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.0990 - digit4_accuracy: 0.0992 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1018 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0975
# Epoch 26/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0995 - digit1_accuracy: 0.0997 - digit2_accuracy: 0.0992 - digit3_accuracy: 0.1003 - digit4_accuracy: 0.0992 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.1004
# Epoch 27/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1001 - digit1_accuracy: 0.0984 - digit2_accuracy: 0.0996 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.1003 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1003 - val_digit1_accuracy: 0.0980 - val_digit2_accuracy: 0.0982 - val_digit3_accuracy: 0.1022 - val_digit4_accuracy: 0.1004
# Epoch 28/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0983 - digit1_accuracy: 0.1004 - digit2_accuracy: 0.0990 - digit3_accuracy: 0.1006 - digit4_accuracy: 0.0993 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0994 - val_digit1_accuracy: 0.0995 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.1009 - val_digit4_accuracy: 0.1007
# Epoch 29/50
# 1702/1702 [==============================] - 31s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0988 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0986 - digit3_accuracy: 0.0996 - digit4_accuracy: 0.1002 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.0982 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.0975
# Epoch 30/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0990 - digit1_accuracy: 0.0985 - digit2_accuracy: 0.0982 - digit3_accuracy: 0.0994 - digit4_accuracy: 0.0996 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.1014
# Epoch 31/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.0994 - digit2_accuracy: 0.1002 - digit3_accuracy: 0.0998 - digit4_accuracy: 0.1000 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.0995 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.1009 - val_digit4_accuracy: 0.1004
# Epoch 32/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0992 - digit1_accuracy: 0.0995 - digit2_accuracy: 0.1000 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.0985 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.0993 - val_digit3_accuracy: 0.0978 - val_digit4_accuracy: 0.0979
# Epoch 33/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6254 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.1008 - digit2_accuracy: 0.0997 - digit3_accuracy: 0.1004 - digit4_accuracy: 0.0998 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.0979 - val_digit3_accuracy: 0.0978 - val_digit4_accuracy: 0.1026
# Epoch 34/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0993 - digit1_accuracy: 0.1003 - digit2_accuracy: 0.0994 - digit3_accuracy: 0.0997 - digit4_accuracy: 0.0992 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.1006 - val_digit2_accuracy: 0.0993 - val_digit3_accuracy: 0.1022 - val_digit4_accuracy: 0.1007
# Epoch 35/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0998 - digit1_accuracy: 0.0993 - digit2_accuracy: 0.0994 - digit3_accuracy: 0.0998 - digit4_accuracy: 0.0995 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.0986 - val_digit4_accuracy: 0.1004
# Epoch 36/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1007 - digit1_accuracy: 0.0993 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.0996 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1018 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.0986 - val_digit4_accuracy: 0.1004
# Epoch 37/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0999 - digit1_accuracy: 0.0997 - digit2_accuracy: 0.0992 - digit3_accuracy: 0.0999 - digit4_accuracy: 0.1008 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.0993 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.1026
# Epoch 38/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.0993 - digit2_accuracy: 0.0993 - digit3_accuracy: 0.0992 - digit4_accuracy: 0.0998 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1003 - val_digit1_accuracy: 0.1027 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.0974 - val_digit4_accuracy: 0.0979
# Epoch 39/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0989 - digit1_accuracy: 0.0996 - digit2_accuracy: 0.0996 - digit3_accuracy: 0.0998 - digit4_accuracy: 0.0994 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1017 - val_digit1_accuracy: 0.1001 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.1020 - val_digit4_accuracy: 0.1004
# Epoch 40/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0999 - digit1_accuracy: 0.1007 - digit2_accuracy: 0.0992 - digit3_accuracy: 0.1004 - digit4_accuracy: 0.0990 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.1001 - val_digit3_accuracy: 0.0986 - val_digit4_accuracy: 0.0987
# Epoch 41/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0994 - digit1_accuracy: 0.0988 - digit2_accuracy: 0.0994 - digit3_accuracy: 0.0995 - digit4_accuracy: 0.1007 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0971 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.1004
# Epoch 42/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0988 - digit1_accuracy: 0.0993 - digit2_accuracy: 0.0980 - digit3_accuracy: 0.1004 - digit4_accuracy: 0.0997 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0994 - val_digit1_accuracy: 0.0966 - val_digit2_accuracy: 0.0979 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0987
# Epoch 43/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0985 - digit1_accuracy: 0.1002 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.1005 - digit4_accuracy: 0.0993 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1011 - val_digit1_accuracy: 0.1001 - val_digit2_accuracy: 0.0982 - val_digit3_accuracy: 0.1020 - val_digit4_accuracy: 0.0987
# Epoch 44/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0991 - digit1_accuracy: 0.1000 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.1002 - digit4_accuracy: 0.1000 - val_loss: 1.6254 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1017 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.1030 - val_digit4_accuracy: 0.0975
# Epoch 45/50
# 1702/1702 [==============================] - 31s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0990 - digit1_accuracy: 0.0996 - digit2_accuracy: 0.0992 - digit3_accuracy: 0.0988 - digit4_accuracy: 0.0988 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0980 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.1009 - val_digit4_accuracy: 0.0987
# Epoch 46/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0994 - digit1_accuracy: 0.0996 - digit2_accuracy: 0.0985 - digit3_accuracy: 0.1008 - digit4_accuracy: 0.1000 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1018 - val_digit1_accuracy: 0.0972 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.0975
# Epoch 47/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0981 - digit1_accuracy: 0.0998 - digit2_accuracy: 0.0993 - digit3_accuracy: 0.1006 - digit4_accuracy: 0.0997 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0994 - val_digit1_accuracy: 0.1029 - val_digit2_accuracy: 0.1029 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.0987
# Epoch 48/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1001 - digit1_accuracy: 0.1001 - digit2_accuracy: 0.0995 - digit3_accuracy: 0.0989 - digit4_accuracy: 0.1005 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0999 - val_digit1_accuracy: 0.0995 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0973 - val_digit4_accuracy: 0.0979
# Epoch 49/50
# 1702/1702 [==============================] - 32s 19ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.1002 - digit2_accuracy: 0.0998 - digit3_accuracy: 0.0992 - digit4_accuracy: 0.0998 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.0994 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.1022 - val_digit4_accuracy: 0.0979
# Epoch 50/50
# 1702/1702 [==============================] - 31s 18ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.0997 - digit1_accuracy: 0.0997 - digit2_accuracy: 0.0999 - digit3_accuracy: 0.0999 - digit4_accuracy: 0.0990 - val_loss: 1.6255 - val_digit0_loss: 0.3251 - val_digit1_loss: 0.3251 - val_digit2_loss: 0.3251 - val_digit3_loss: 0.3251 - val_digit4_loss: 0.3251 - val_digit0_accuracy: 0.1003 - val_digit1_accuracy: 0.1006 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.0963 - val_digit4_accuracy: 0.0987

# %%
digit_acc = [[] for _ in range(NUM_OF_LETTERS)]
val_digit_acc = [[] for _ in range(NUM_OF_LETTERS)]
loss = []
val_loss = []


def plot_diagram(digit_acc_now, val_digit_acc_now, loss_now, val_loss_now):
    global digit_acc, val_digit_acc, loss, val_loss
    
    for i in range(NUM_OF_LETTERS):
        digit_acc[i].extend(digit_acc_now[i])
        val_digit_acc[i].extend(val_digit_acc_now[i])
    loss.extend(loss_now)
    val_loss.extend(val_loss_now)
    
    for i in range(NUM_OF_LETTERS):
        s = {0:'First', 1:'Second', 2:'Third', 3:'Fourth', 4:'Fifth'}[i]
        # plt.plot(val_digit_acc[i], label='%s Digit Train' % s)
        plt.plot(digit_acc[i], label='%s Digit Test' % s)

    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    for i in range(NUM_OF_LETTERS):
        s = {0:'First', 1:'Second', 2:'Third', 3:'Fourth', 4:'Fifth'}[i]
        plt.plot(val_digit_acc[i], label='%s Digit Train' % s)
        # plt.plot(digit_acc[i], label='%s Digit Test' % s)

    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()



    # Plot training & validation loss values
    plt.plot(val_loss, label='Train')
    plt.plot(loss, label='Test')
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
plot_diagram(
    
    [history.history['digit%d_accuracy' % i] for i in range(NUM_OF_LETTERS)],
    [history.history['val_digit%d_accuracy' % i] for i in range(NUM_OF_LETTERS)],
    history.history['loss'],
    history.history['val_loss'],
)

# %%
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5

# %%
# Score trained model.
scores = model.evaluate(x_train, s_train, verbose=1)
print('Train loss:     %f' % np.mean(scores[0:5]))
acc = 1.
for i in range(5):
    acc *= scores[6+i]
print('Train accuracy: %.2f' % (acc * 100.))
# Out:
# 6807/6807 [==============================] - 32s 5ms/step - loss: 1.6254 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1000 - digit1_accuracy: 0.0999 - digit2_accuracy: 0.0999 - digit3_accuracy: 0.1004 - digit4_accuracy: 0.1001
# Train loss:     0.585160
# Train accuracy: 0.00

# %%
scores = model.evaluate(x_test, s_test, verbose=1)
print('Test loss:     %f' % np.mean(scores[0:5]))
acc = 1.
for i in range(5):
    acc *= scores[6+i]
print('Test accuracy: %.2f' % (acc * 100.))
# Out:
# 754/754 [==============================] - 4s 5ms/step - loss: 1.6255 - digit0_loss: 0.3251 - digit1_loss: 0.3251 - digit2_loss: 0.3251 - digit3_loss: 0.3251 - digit4_loss: 0.3251 - digit0_accuracy: 0.1003 - digit1_accuracy: 0.1006 - digit2_accuracy: 0.1007 - digit3_accuracy: 0.0963 - digit4_accuracy: 0.0987
# Test loss:     0.585171
# Test accuracy: 0.00
